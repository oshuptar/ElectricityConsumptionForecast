# %%
# !pwd
# %pip install -r ../requirements.txt

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)

# %% [markdown]
# ### Testing Dataloaders

# %%
# %cd ..
from src.dataset import (
    get_dataset,
    get_data_loaders
)

train_dataset, test_dataset = get_dataset(window_size=5)
train_loader, test_loader = get_data_loaders(train_dataset=train_dataset, test_dataset=test_dataset)
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")

# %% [markdown]
# ## Lab Assignment

# %%
# %load_ext autoreload
# %autoreload 2
print("Successfully activated .py files autoreload")
# after editing the file, running the cell again will make it use the new code

# %%
# %matplotlib inline

# %% [markdown]
# Run from the project root:

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
# Column names: Index(['timestamp', 'consumption'], dtype='str'). Dataframe shape: (105215, 2). Data types: timestamp      datetime64[us]
# consumption           float64
# dtype: object
# Q5:
# Model architecture: ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=5760, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
#
# Epoch 1/5 - Train Loss: 0.1698
# Test results:
# Criterion: MAE. Score: 0.22295271758169066
# Criterion: RMSE. Score: 0.27392746783044664
# Criterion: MAPE. Score: 153.61177332536622
#
# Epoch 2/5 - Train Loss: 0.0703
# Test results:
# Criterion: MAE. Score: 0.18519404560620348
# Criterion: RMSE. Score: 0.23507007447327588
# Criterion: MAPE. Score: 129.4692568435419
#
# Epoch 3/5 - Train Loss: 0.0618
# Test results:
# Criterion: MAE. Score: 0.17844066916920212
# Criterion: RMSE. Score: 0.22863663012348928
# Criterion: MAPE. Score: 133.25404273578692
#
# Epoch 4/5 - Train Loss: 0.0587
# Test results:
# Criterion: MAE. Score: 0.1587499897422749
# Criterion: RMSE. Score: 0.20891539567845618
# Criterion: MAPE. Score: 119.45609826604351
#
# Epoch 5/5 - Train Loss: 0.0566
# Test results:
# Criterion: MAE. Score: 0.1707123766722377
# Criterion: RMSE. Score: 0.2174392743402173
# Criterion: MAPE. Score: 113.9063940089863
#
# Q7: - running the hyperparameter tunning
# Column names: Index(['timestamp', 'consumption'], dtype='str'). Dataframe shape: (105215, 2). Data types: timestamp      datetime64[us]
# consumption           float64
# dtype: object
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1266
# Test results:
# Criterion: MAE. Score: 0.2105950340628624
#
# Epoch 2/3 - Train Loss: 0.0649
# Test results:
# Criterion: MAE. Score: 0.21025334706772927
#
# Epoch 3/3 - Train Loss: 0.0511
# Test results:
# Criterion: MAE. Score: 0.18279119561547819
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1511
# Test results:
# Criterion: MAE. Score: 0.22472458820918512
#
# Epoch 2/3 - Train Loss: 0.0716
# Test results:
# Criterion: MAE. Score: 0.19695506707347674
#
# Epoch 3/3 - Train Loss: 0.0552
# Test results:
# Criterion: MAE. Score: 0.1963482923034964
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1345
# Test results:
# Criterion: MAE. Score: 0.21749561973240064
#
# Epoch 2/3 - Train Loss: 0.0646
# Test results:
# Criterion: MAE. Score: 0.19560015175653542
#
# Epoch 3/3 - Train Loss: 0.0495
# Test results:
# Criterion: MAE. Score: 0.18904654552107272
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1648
# Test results:
# Criterion: MAE. Score: 0.2333307551412747
#
# Epoch 2/3 - Train Loss: 0.0749
# Test results:
# Criterion: MAE. Score: 0.20260420595777445
#
# Epoch 3/3 - Train Loss: 0.0555
# Test results:
# Criterion: MAE. Score: 0.20287937259879604
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1245
# Test results:
# Criterion: MAE. Score: 0.20777635509553163
#
# Epoch 2/3 - Train Loss: 0.0659
# Test results:
# Criterion: MAE. Score: 0.20185464445663534
#
# Epoch 3/3 - Train Loss: 0.0498
# Test results:
# Criterion: MAE. Score: 0.1819775068241617
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1418
# Test results:
# Criterion: MAE. Score: 0.22139422415659346
#
# Epoch 2/3 - Train Loss: 0.0686
# Test results:
# Criterion: MAE. Score: 0.21246315667341495
#
# Epoch 3/3 - Train Loss: 0.0526
# Test results:
# Criterion: MAE. Score: 0.2088925558431395
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1340
# Test results:
# Criterion: MAE. Score: 0.20456499697073646
#
# Epoch 2/3 - Train Loss: 0.0626
# Test results:
# Criterion: MAE. Score: 0.19113616833220357
#
# Epoch 3/3 - Train Loss: 0.0492
# Test results:
# Criterion: MAE. Score: 0.18732365881619245
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1544
# Test results:
# Criterion: MAE. Score: 0.23045998246505342
#
# Epoch 2/3 - Train Loss: 0.0740
# Test results:
# Criterion: MAE. Score: 0.2017557993531227
#
# Epoch 3/3 - Train Loss: 0.0545
# Test results:
# Criterion: MAE. Score: 0.19309746371261005
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1271
# Test results:
# Criterion: MAE. Score: 0.2105016373421835
#
# Epoch 2/3 - Train Loss: 0.0629
# Test results:
# Criterion: MAE. Score: 0.18872962425584378
#
# Epoch 3/3 - Train Loss: 0.0505
# Test results:
# Criterion: MAE. Score: 0.183597787178081
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1445
# Test results:
# Criterion: MAE. Score: 0.22655626823162212
#
# Epoch 2/3 - Train Loss: 0.0705
# Test results:
# Criterion: MAE. Score: 0.19700667159310703
#
# Epoch 3/3 - Train Loss: 0.0553
# Test results:
# Criterion: MAE. Score: 0.20253116457626738
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1207
# Test results:
# Criterion: MAE. Score: 0.20386849978695745
#
# Epoch 2/3 - Train Loss: 0.0601
# Test results:
# Criterion: MAE. Score: 0.19708244709864906
#
# Epoch 3/3 - Train Loss: 0.0470
# Test results:
# Criterion: MAE. Score: 0.18499741748623225
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1518
# Test results:
# Criterion: MAE. Score: 0.21947286252317758
#
# Epoch 2/3 - Train Loss: 0.0705
# Test results:
# Criterion: MAE. Score: 0.2001662665400012
#
# Epoch 3/3 - Train Loss: 0.0529
# Test results:
# Criterion: MAE. Score: 0.1959649085484702
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1316
# Test results:
# Criterion: MAE. Score: 0.2135357945509579
#
# Epoch 2/3 - Train Loss: 0.0640
# Test results:
# Criterion: MAE. Score: 0.19956204612617906
#
# Epoch 3/3 - Train Loss: 0.0508
# Test results:
# Criterion: MAE. Score: 0.18538799007301746
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1402
# Test results:
# Criterion: MAE. Score: 0.22588460018922543
#
# Epoch 2/3 - Train Loss: 0.0689
# Test results:
# Criterion: MAE. Score: 0.20120561379810858
#
# Epoch 3/3 - Train Loss: 0.0507
# Test results:
# Criterion: MAE. Score: 0.19091527600740565
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.1236
# Test results:
# Criterion: MAE. Score: 0.23173594319302102
#
# Epoch 2/3 - Train Loss: 0.0605
# Test results:
# Criterion: MAE. Score: 0.20417653069547984
#
# Epoch 3/3 - Train Loss: 0.0465
# Test results:
# Criterion: MAE. Score: 0.19751385249521422
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.1584
# Test results:
# Criterion: MAE. Score: 0.22445241413239775
#
# Epoch 2/3 - Train Loss: 0.0725
# Test results:
# Criterion: MAE. Score: 0.20899478114884476
#
# Epoch 3/3 - Train Loss: 0.0539
# Test results:
# Criterion: MAE. Score: 0.20630087292399898
#
# Best configurations:
# 1. {'hidden1_size': 64, 'hidden2_size': 64, 'learning_rate': 0.001, 'batch_size': 256, 'mae': 0.1819775068241617, 'model': ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=5760, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=1, bias=True)
#   )
# )}
# 2. {'hidden1_size': 64, 'hidden2_size': 32, 'learning_rate': 0.001, 'batch_size': 256, 'mae': 0.18279119561547819, 'model': ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=5760, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )}
# 3. {'hidden1_size': 128, 'hidden2_size': 32, 'learning_rate': 0.001, 'batch_size': 256, 'mae': 0.183597787178081, 'model': ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=5760, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )}
#
# Q8 - plotting predicted vs actual on a test dataset
# The plot file was saved to /home/shuptik/pw/sem6/ann/ElectricityConsumptionForecast/plots/week_plot.png
# The plot file was saved to /home/shuptik/pw/sem6/ann/ElectricityConsumptionForecast/plots/year_plot.png
#
# (Q9 & Q10) - forecast for 2015
# -1.0516337 1.4634846 0.529004
# [ 0.38081464  0.3493758   0.3192071   0.29939857  0.2918611   0.27666333
#   0.24963546  0.2125152   0.17434454  0.12427374  0.04755405 -0.02491626
#  -0.07678568 -0.11119092 -0.14315641 -0.15493795 -0.15982938 -0.15766601
#  -0.15387134 -0.15702307 -0.15441531 -0.15295763 -0.16104484 -0.18432711
#  -0.20206062 -0.18671492 -0.11996416 -0.00159498  0.08454897  0.12478066
#   0.13617834  0.15156004  0.17077142  0.1864281   0.19720098  0.20400605
#   0.20189786  0.19362804  0.16697958  0.13497815  0.10734832  0.0894051
#   0.08237366  0.08481696  0.09142896  0.09786353  0.0979593   0.08382612
#   0.05953301  0.02570064]
# [ 0.09546233  0.21062815  0.37714258  0.52629584  0.5962835   0.7002848
#   0.74735624  0.8043944   0.82188416  0.80632085  0.7421566   0.44223663
#   0.3676166   0.34891188  0.3270282   0.30305952  0.19448191  0.09529612
#   0.01577608 -0.03007241 -0.15087453 -0.24263892 -0.27507704 -0.21887675
#   0.09968526  0.16710752  0.1391828   0.15590164  0.10742251  0.12697932
#   0.14479968  0.21867019  0.262921    0.27569157  0.24009216  0.2764548
#   0.2857714   0.293139    0.3260912   0.31989065  0.28870532  0.27045286
#   0.24294576  0.2053845   0.15613294  0.1413587   0.14641866  0.14113206
#   0.14255211  0.18255374]
# The plot file was saved to /home/shuptik/pw/sem6/ann/ElectricityConsumptionForecast/plots/forecast_plot.png
