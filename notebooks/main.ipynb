# %%
# !pwd
# %pip install -r ../requirements.txt

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)

# %% [markdown]
# ### Testing Dataloaders

# %%
# %cd ..
from src.dataset import (
    get_dataset,
    get_data_loaders
)

train_dataset, test_dataset = get_dataset(window_size=5)
train_loader, test_loader = get_data_loaders(train_dataset=train_dataset, test_dataset=test_dataset)
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")

# %% [markdown]
# ## Lab Assignment

# %%
# %load_ext autoreload
# %autoreload 2
print("Successfully activated .py files autoreload")
# after editing the file, running the cell again will make it use the new code
# Out:
# Successfully activated .py files autoreload

# %%
# %matplotlib inline

# %% [markdown]
# Run from the project root:

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
# Column names: Index(['timestamp', 'consumption'], dtype='str'). Dataframe shape: (105215, 2). Data types: timestamp      datetime64[us]
# consumption           float64
# dtype: object
# Q5:
# Model architecture: ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
#
# Epoch 1/5 - Train Loss: 0.1009
# Test results:
# Criterion: MAE. Score: 0.10900240733770884
# Criterion: RMSE. Score: 0.1809745779818427
# Criterion: MAPE. Score: 72.15838576929413
#
# Epoch 2/5 - Train Loss: 0.0559
# Test results:
# Criterion: MAE. Score: 0.10691206755429289
# Criterion: RMSE. Score: 0.1783687300150738
# Criterion: MAPE. Score: 73.24227587149961
#
# Epoch 3/5 - Train Loss: 0.0541
# Test results:
# Criterion: MAE. Score: 0.1086966912432091
# Criterion: RMSE. Score: 0.17904005922295535
# Criterion: MAPE. Score: 74.42861837018145
#
# Epoch 4/5 - Train Loss: 0.0533
# Test results:
# Criterion: MAE. Score: 0.11018048026293081
# Criterion: RMSE. Score: 0.17975452231637534
# Criterion: MAPE. Score: 75.21995500230442
#
# Epoch 5/5 - Train Loss: 0.0527
# Test results:
# Criterion: MAE. Score: 0.11676629577647812
# Criterion: RMSE. Score: 0.18369520161246514
# Criterion: MAPE. Score: 74.03650689168568
#
# Q7: - running the hyperparameter tunning
# Column names: Index(['timestamp', 'consumption'], dtype='str'). Dataframe shape: (105215, 2). Data types: timestamp      datetime64[us]
# consumption           float64
# dtype: object
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.5384
# Test results:
# Criterion: MAE. Score: 0.269979282778545
#
# Epoch 2/3 - Train Loss: 0.1915
# Test results:
# Criterion: MAE. Score: 0.19746916191856356
#
# Epoch 3/3 - Train Loss: 0.1607
# Test results:
# Criterion: MAE. Score: 0.18207702687839522
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.6748
# Test results:
# Criterion: MAE. Score: 0.37609063931133435
#
# Epoch 2/3 - Train Loss: 0.2661
# Test results:
# Criterion: MAE. Score: 0.23117478537386743
#
# Epoch 3/3 - Train Loss: 0.1915
# Test results:
# Criterion: MAE. Score: 0.199748362104098
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 1.0218
# Test results:
# Criterion: MAE. Score: 0.5724848182532039
#
# Epoch 2/3 - Train Loss: 0.7351
# Test results:
# Criterion: MAE. Score: 0.4806820780691439
#
# Epoch 3/3 - Train Loss: 0.5149
# Test results:
# Criterion: MAE. Score: 0.38356010942128455
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.9275
# Test results:
# Criterion: MAE. Score: 0.577202038920444
#
# Epoch 2/3 - Train Loss: 0.7170
# Test results:
# Criterion: MAE. Score: 0.5080780097539874
#
# Epoch 3/3 - Train Loss: 0.5555
# Test results:
# Criterion: MAE. Score: 0.4428015562935152
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.4857
# Test results:
# Criterion: MAE. Score: 0.24214543924279455
#
# Epoch 2/3 - Train Loss: 0.2028
# Test results:
# Criterion: MAE. Score: 0.2002548673292146
#
# Epoch 3/3 - Train Loss: 0.1667
# Test results:
# Criterion: MAE. Score: 0.17977658512383482
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.7357
# Test results:
# Criterion: MAE. Score: 0.42721737554107886
#
# Epoch 2/3 - Train Loss: 0.3210
# Test results:
# Criterion: MAE. Score: 0.27238918948864593
#
# Epoch 3/3 - Train Loss: 0.2242
# Test results:
# Criterion: MAE. Score: 0.22528970911019092
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.8720
# Test results:
# Criterion: MAE. Score: 0.5151886604998234
#
# Epoch 2/3 - Train Loss: 0.4974
# Test results:
# Criterion: MAE. Score: 0.38110919992854125
#
# Epoch 3/3 - Train Loss: 0.3049
# Test results:
# Criterion: MAE. Score: 0.29069307827166396
#
# --------------------------------------------------
#
# hidden1=64, hidden2=64, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.9313
# Test results:
# Criterion: MAE. Score: 0.5550893730875375
#
# Epoch 2/3 - Train Loss: 0.6590
# Test results:
# Criterion: MAE. Score: 0.45889146993125696
#
# Epoch 3/3 - Train Loss: 0.4697
# Test results:
# Criterion: MAE. Score: 0.378752165298531
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.4262
# Test results:
# Criterion: MAE. Score: 0.22822177856072892
#
# Epoch 2/3 - Train Loss: 0.1659
# Test results:
# Criterion: MAE. Score: 0.1712244522832606
#
# Epoch 3/3 - Train Loss: 0.1293
# Test results:
# Criterion: MAE. Score: 0.15106146970260753
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.6868
# Test results:
# Criterion: MAE. Score: 0.36846259495486383
#
# Epoch 2/3 - Train Loss: 0.2596
# Test results:
# Criterion: MAE. Score: 0.2341373424599136
#
# Epoch 3/3 - Train Loss: 0.1889
# Test results:
# Criterion: MAE. Score: 0.20209296803543533
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.6331
# Test results:
# Criterion: MAE. Score: 0.4032586098369891
#
# Epoch 2/3 - Train Loss: 0.3099
# Test results:
# Criterion: MAE. Score: 0.2717762095649747
#
# Epoch 3/3 - Train Loss: 0.2106
# Test results:
# Criterion: MAE. Score: 0.21644763882360318
#
# --------------------------------------------------
#
# hidden1=128, hidden2=32, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.9317
# Test results:
# Criterion: MAE. Score: 0.5772205539371656
#
# Epoch 2/3 - Train Loss: 0.6699
# Test results:
# Criterion: MAE. Score: 0.4939137943412947
#
# Epoch 3/3 - Train Loss: 0.4958
# Test results:
# Criterion: MAE. Score: 0.4205320080121358
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.4617
# Test results:
# Criterion: MAE. Score: 0.22547273365032933
#
# Epoch 2/3 - Train Loss: 0.1854
# Test results:
# Criterion: MAE. Score: 0.18894290706537065
#
# Epoch 3/3 - Train Loss: 0.1471
# Test results:
# Criterion: MAE. Score: 0.16699331476740595
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.6437
# Test results:
# Criterion: MAE. Score: 0.35233113169670105
#
# Epoch 2/3 - Train Loss: 0.2583
# Test results:
# Criterion: MAE. Score: 0.23643260287201923
#
# Epoch 3/3 - Train Loss: 0.2012
# Test results:
# Criterion: MAE. Score: 0.207625449999519
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.0003, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.8113
# Test results:
# Criterion: MAE. Score: 0.45317504593055613
#
# Epoch 2/3 - Train Loss: 0.3565
# Test results:
# Criterion: MAE. Score: 0.29919342577022356
#
# Epoch 3/3 - Train Loss: 0.2389
# Test results:
# Criterion: MAE. Score: 0.23641950033441947
#
# --------------------------------------------------
#
# hidden1=128, hidden2=64, lr=0.0003, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.9052
# Test results:
# Criterion: MAE. Score: 0.5390750290690989
#
# Epoch 2/3 - Train Loss: 0.5675
# Test results:
# Criterion: MAE. Score: 0.4348980987417525
#
# Epoch 3/3 - Train Loss: 0.3889
# Test results:
# Criterion: MAE. Score: 0.3557034260120945
#
# Best configurations:
# 1. {'hidden1_size': 128, 'hidden2_size': 32, 'learning_rate': 0.001, 'batch_size': 256, 'mae': 0.15106146970260753, 'model': ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )}
# 2. {'hidden1_size': 128, 'hidden2_size': 64, 'learning_rate': 0.001, 'batch_size': 256, 'mae': 0.16699331476740595, 'model': ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=1, bias=True)
#   )
# )}
# 3. {'hidden1_size': 64, 'hidden2_size': 64, 'learning_rate': 0.001, 'batch_size': 256, 'mae': 0.17977658512383482, 'model': ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=1, bias=True)
#   )
# )}
#
# Q8 - plotting predicted vs actual on a test dataset
# The plot file was saved to /home/shuptik/pw/sem6/ann/ElectricityConsumptionForecast/src/../plots/week_plot.png
