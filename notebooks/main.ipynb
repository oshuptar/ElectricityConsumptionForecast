# %%
# !pwd
# %pip install -r ../requirements.txt

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)

# %% [markdown]
# ### Testing Dataloaders

# %%
# %cd ..
from src.dataset import (
    get_dataset,
    get_data_loaders
)

train_dataset, test_dataset = get_dataset(window_size=5)
train_loader, test_loader = get_data_loaders(train_dataset=train_dataset, test_dataset=test_dataset)
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")

# %% [markdown]
# ## Lab Assignment

# %%
# %load_ext autoreload
# %autoreload 2
print("Successfully activated .py files autoreload")
# after editing the file, running the cell again will make it use the new code
# Out:
# Successfully activated .py files autoreload

# %% [markdown]
# ### Q1:

# %% [markdown]
# Run from the project root:

# %%
# !python ./main.py
# Out:
# Q5:
# GPU not available, using CPU
# Column names: Index(['timestamp', 'consumption'], dtype='str'). Dataframe shape: (105215, 2). Data types: timestamp          str
# consumption    float64
# dtype: object
# Model architecture: ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=16, out_features=1, bias=True)
#   )
# )
# Epoch 1/5 - Train Loss: 0.1152
# Test results:
# Mean Absolute Error 0.11410728870911428
# Root Mean Squared Error 0.1873056120545107
# Mean Absolute percentage error 79.65383673236317%
#
# Epoch 2/5 - Train Loss: 0.0599
# Test results:
# Mean Absolute Error 0.1103652885700338
# Root Mean Squared Error 0.18255457624344387
# Mean Absolute percentage error 77.38723505609227%
#
# Epoch 3/5 - Train Loss: 0.0564
# Test results:
# Mean Absolute Error 0.10891675966431516
# Root Mean Squared Error 0.18137292284178583
# Mean Absolute percentage error 76.74714945789671%
#
# Epoch 4/5 - Train Loss: 0.0549
# Test results:
# Mean Absolute Error 0.11483051174449442
# Root Mean Squared Error 0.18297639047985312
# Mean Absolute percentage error 77.94363325138161%
#
# Epoch 5/5 - Train Loss: 0.0539
# Test results:
# Mean Absolute Error 0.11272640834922773
# Root Mean Squared Error 0.18175673248912513
# Mean Absolute percentage error 76.86011912004791%
