# %%
# !pwd
# %pip install -r ../requirements.txt

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)

# %% [markdown]
# ### Testing Dataloaders

# %%
# %cd ..
from src.dataset import (
    get_dataset,
    get_data_loaders
)

train_dataset, test_dataset = get_dataset(window_size=5)
train_loader, test_loader = get_data_loaders(train_dataset=train_dataset, test_dataset=test_dataset)
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")

# %% [markdown]
# ## Lab Assignment

# %%
# %load_ext autoreload
# %autoreload 2
print("Successfully activated .py files autoreload")
# after editing the file, running the cell again will make it use the new code
# Out:
# Successfully activated .py files autoreload

# %% [markdown]
# ### Q1:

# %% [markdown]
# Run from the project root:

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
# Column names: Index(['timestamp', 'consumption'], dtype='str'). Dataframe shape: (105215, 2). Data types: timestamp          str
# consumption    float64
# dtype: object
# Q5:
# Model architecture: ForecastModel(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
#
# Epoch 1/5 - Train Loss: 0.0920
# Test results:
# Criterion: MAE. Score: 0.10907995993489006
# Criterion: RMSE. Score: 0.18267971357113144
# Criterion: MAPE. Score: 74.07368853448952
#
# Epoch 2/5 - Train Loss: 0.0574
# Test results:
# Criterion: MAE. Score: 0.11315423858957026
# Criterion: RMSE. Score: 0.1826846584793262
# Criterion: MAPE. Score: 72.40355155067722
#
# Epoch 3/5 - Train Loss: 0.0551
# Test results:
# Criterion: MAE. Score: 0.11428017380994059
# Criterion: RMSE. Score: 0.18262180113607515
# Criterion: MAPE. Score: 72.24070863828172
#
# Epoch 4/5 - Train Loss: 0.0541
# Test results:
# Criterion: MAE. Score: 0.11552672960326402
# Criterion: RMSE. Score: 0.18420162801732765
# Criterion: MAPE. Score: 73.56536225202309
#
# Epoch 5/5 - Train Loss: 0.0535
# Test results:
# Criterion: MAE. Score: 0.11191255262080771
# Criterion: RMSE. Score: 0.1815493649286456
# Criterion: MAPE. Score: 72.95170103851027
#
# Q7: - running the hyperparameter tunning
# Column names: Index(['timestamp', 'consumption'], dtype='str'). Dataframe shape: (105215, 2). Data types: timestamp          str
# consumption    float64
# dtype: object
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.001, batch_size=256
#
# Epoch 1/3 - Train Loss: 0.5943
# Test results:
# Criterion: MAE. Score: 0.29686762436027947
#
# Epoch 2/3 - Train Loss: 0.2125
# Test results:
# Criterion: MAE. Score: 0.1936168730476477
#
# Epoch 3/3 - Train Loss: 0.1598
# Test results:
# Criterion: MAE. Score: 0.17036065834499622
#
# --------------------------------------------------
#
# hidden1=64, hidden2=32, lr=0.001, batch_size=512
#
# Epoch 1/3 - Train Loss: 0.7773
# Test results:
# Criterion: MAE. Score: 0.48618433397749194
#
# Epoch 2/3 - Train Loss: 0.4294
# Test results:
# Criterion: MAE. Score: 0.3606984861519026
#
# Epoch 3/3 - Train Loss: 0.2883
# Test results:
